# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("breast_cancer.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
print(df.isnull().sum())
print("569 Missing values in column Unnamed: 32, which is unrelevant to be included.")
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
#Check duplicated data
print("Duplicated data: ", df.duplicated().sum())
# Out:
# Duplicated data:  0

# %%
#remove column id and Unnamed: 32
df.drop(columns= ["id", "Unnamed: 32"], inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#Mean of Dataframe
print("Dataframe mean:")
df.mean()
# Out:
# Dataframe mean:
# radius_mean                 14.127292
# texture_mean                19.289649
# perimeter_mean              91.969033
# area_mean                  654.889104
# smoothness_mean              0.096360
# compactness_mean             0.104341
# concavity_mean               0.088799
# concave points_mean          0.048919
# symmetry_mean                0.181162
# fractal_dimension_mean       0.062798
# radius_se                    0.405172
# texture_se                   1.216853
# perimeter_se                 2.866059
# area_se                     40.337079
# smoothness_se                0.007041
# compactness_se               0.025478
# concavity_se                 0.031894
# concave points_se            0.011796
# symmetry_se                  0.020542
# fractal_dimension_se         0.003795
# radius_worst                16.269190
# texture_worst               25.677223
# perimeter_worst            107.261213
# area_worst                 880.583128
# ...

# %%
#Correlation of Dataframe
corr = df.corr()
corr
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
count_diagnosis = df["diagnosis"].value_counts()
count_diagnosis
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
df["diagnosis"].replace(["B", "M"], [0, 1], inplace = True)
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# Diagnose:
# Benign = 0
# Maligne = 1

# %%
sns.countplot(x = df["diagnosis"], data = df)
plt.show()

# %%
plt.figure(figsize=(10,10))
count_diagnosis.plot(kind = "pie", autopct = "%1.1f%%", startangle = 0, labels=["Benign", "Malignant"], explode = [0, 0.1], colors = ["lightsalmon", "palegreen"], shadow=True)
plt.legend()
plt.title("Diagnosis Proportion", fontsize = 30)
plt.axis("off")
plt.show()

# %%
from sklearn.model_selection import train_test_split

x = df.drop(columns=["diagnosis"], axis=1)
y = df["diagnosis"]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
X = scaler.transform(x)
X = pd.DataFrame(X)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

depth = range(1, 35)
test_accuracy = list()
train_accuracy = list()
score = 0

for i in depth:
    tree = DecisionTreeClassifier(max_depth = i, criterion = 'entropy')
    tree.fit(x_train, y_train)
    yhat_train = tree.predict(x_train)
    train_accuracy.append(accuracy_score(y_train, yhat_train))
    
    yhat_test = tree.predict(x_test)
    accuracy = accuracy_score(y_test,yhat_test)
    test_accuracy.append(accuracy)
    
    if score < accuracy:
        score = accuracy
        best_depth = i
        
plt.figure(figsize = (11, 11))
plt.plot(depth, train_accuracy, '-o', label='Train Accuracy')
plt.plot(depth, test_accuracy, '-o', label='Test Accuracy')
plt.legend()
plt.show()

# %%
print("Based on the plot above, choose max_depth = ", best_depth, "and accuracy from Decision Tree Classifier: ", score*100, "%")
print("The model is overfitting since the train accuracy increased to 1.00 and the test accuracy slightly decreased.")
# Out:
# Based on the plot above, choose max_depth =  3 and accuracy from Decision Tree Classifier:  97.07602339181285 %
# The model is overfitting since the train accuracy increased to 1.00 and the test accuracy slightly decreased.

# %%
tree = DecisionTreeClassifier(max_depth = 3)

# %%
from sklearn.model_selection import GridSearchCV

parameters = {"splitter":["best","random"], "criterion" : ["gini", "entropy"], "max_depth" : [3,5,7,9,11,12]}

tuning = GridSearchCV(tree ,param_grid=parameters, cv=5)
tuning.fit(x_train, y_train)
print("Best parameters to use for Decision Tree: ", tuning.best_params_)
# Out:
# Best parameters to use for Decision Tree:  {'criterion': 'gini', 'max_depth': 5, 'splitter': 'random'}
# C:\Users\maisy\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:813: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
tree2 = DecisionTreeClassifier(criterion = "entropy", max_depth = 12, splitter = "best")
tree.fit(x_train, y_train)
print("Accuracy after Hyperparameter tuning: ", tree.score(x_test, y_test)*100, "%")
# Out:
# Accuracy after Hyperparameter tuning:  95.90643274853801 %
